# %%
from Programas.ProgramasGraficas import *

# %%
#gra3d(mapeo,xmin, xmax, ymin,ymax,guarda=False,malla=True,actilim=True):
gra3d('sin(x)+cos(y)',-5,5,-5,5,guarda=True)

# %%
#gra3dp(mapeo,mapeo2,xmin, xmax, ymin,ymax,guarda=False,malla=True,actilim=True):
gra3dp('sin((x**2+y**2)**0.5)','0.1*x+0.1*y+1.2',-4,4,-4,4)

# %%
gra2di('sin(x)',(-5,5),-1,3)

# %%
gra2di('exp(-x)*sin(x)',(0,6),1,2)

# %%
#cuadrosampler(filas,columnas,colores)
cuadrosampler(10,10,2)

# %%
#cuadrosampler(filas,columnas,colores)
cuadrosampler(20,20,5)
